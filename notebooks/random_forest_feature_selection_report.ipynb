# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
# Out:
# /Users/natalie/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
df = pd.read_csv('/Users/natalie/Desktop/DS Thesis/user-churn-prediction/outputs/random_forest_feature_selection.csv')

# %%
df
# Out:
#       model_name  accuracy_score  f1_score  auc_score  specificity_score  \
# 0        log_reg        0.821430  0.763763   0.878839           0.870765
# 1   randomforest        0.831390  0.780192   0.897537           0.869779
# 2       lightgbm        0.830575  0.781242   0.899517           0.864120
# 3        xgboost        0.830775  0.781172   0.899434           0.865060
# 4            mlp        0.828255  0.777924   0.896526           0.863365
# 5        log_reg        0.824080  0.763896   0.879435           0.879675
# 6   randomforest        0.827780  0.779592   0.896402           0.857434
# 7       lightgbm        0.832790  0.782566   0.900184           0.869375
# 8        xgboost        0.831520  0.782166   0.900118           0.865477
# 9            mlp        0.826385  0.778190   0.896955           0.855554
# 10       log_reg        0.821125  0.763073   0.879034           0.871176
# 11  randomforest        0.825135  0.777650   0.894999           0.852072
# 12      lightgbm        0.832850  0.782706   0.900272           0.869263
# 13       xgboost        0.830220  0.782616   0.900520           0.859301
# 14           mlp        0.822840  0.776885   0.896754           0.845069
# 15       log_reg        0.821710  0.763040   0.878179           0.873281
# 16  randomforest        0.822810  0.776609   0.894238           0.845665
# 17      lightgbm        0.830990  0.782136   0.900495           0.863504
# 18       xgboost        0.831610  0.782664   0.900900           0.864590
# 19           mlp        0.825605  0.777771   0.895912           0.853588
# 20       log_reg        0.825115  0.764974   0.878411           0.881005
# 21  randomforest        0.824105  0.775613   0.893649           0.853211
# 22      lightgbm        0.831355  0.782650   0.900551           0.863636
# 23       xgboost        0.832345  0.783407   0.900940           0.865589
# 24           mlp        0.824540  0.777274   0.896408           0.850716
# 25       log_reg        0.822205  0.763743   0.878762           0.873512
# 26  randomforest        0.819345  0.769846   0.890187           0.849319
# 27      lightgbm        0.831110  0.782522   0.900589           0.863008
# 28       xgboost        0.832530  0.783839   0.901200           0.865232
# 29           mlp        0.829700  0.778736   0.896811           0.866880
# 30       log_reg        0.822345  0.763644   0.878688           0.874207
# 31  randomforest        0.817675  0.764139   0.887284           0.856600
# 32      lightgbm        0.833010  0.782841   0.900574           0.869547
# 33       xgboost        0.832300  0.783515   0.901103           0.865146
# 34           mlp        0.827505  0.779278   0.897401           0.857156
#
#     sensitivity_score n_features
# 0            0.669092         10
# 1            0.712852         10
# 2            0.726996         10
# 3            0.724911         10
# 4            0.719842         10
# 5            0.652414         20
# 6            0.736214         20
# 7            0.719822         20
# 8            0.726669         20
# 9            0.736316         20
# 10           0.666578         30
# 11           0.741957         30
# 12           0.720415         30
# 13           0.740424         30
# 14           0.754200         30
# 15           0.662470         40
# 16           0.752238         40
# 17           0.730593         40
# 18           0.729776         40
# 19           0.739198         40
# 20           0.652536         50
# 21           0.734231         50
# 22           0.731676         50
# 23           0.729694         50
# 24           0.743715         50
# 25           0.663778        100
# 26           0.726791        100
# 27           0.732617        100
# 28           0.731554        100
# 29           0.714896        100
# 30           0.662204        all
# 31           0.697482        all
# 32           0.720190        all
# 33           0.730879        all
# 34           0.735948        all

# %%
for col in df.columns[1:-1]:
    font = {'size'   : 14}
    matplotlib.rc('font', **font)
    plt.figure(figsize=(10,7))
    sns.lineplot(x='n_features', y=col,data=df, hue='model_name',style='model_name', markers=True,dashes=True)
    plt.axhline(df[col].max(), linestyle='--',color='black')
    plt.title(col)
    plt.show()
